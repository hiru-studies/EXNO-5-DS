# %%
import matplotlib.pyplot as plt

x1 = [1, 2, 3]
y1 = [2, 4, 1]
plt.plot(x1, y1, label='line1')

x2 = [1, 2, 3]
y2 = [4, 1, 3]
plt.plot(x2, y2, label='line2')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Two lines on same graph!')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [2, 4, 3, 5, 2, 7]

plt.plot(x, y, color='blue', linestyle='dashed', linewidth=3,
         marker='s', markerfacecolor='yellow', markersize=7)
plt.ylim(0, 8)
plt.xlim(0, 8)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Some cool customizations!')
plt.show()

# %%
import matplotlib.pyplot as plt

yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
plt.plot(yield_apples)
plt.show()

# %%
import matplotlib.pyplot as plt

years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.plot(years, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.show()

# %%
import matplotlib.pyplot as plt

years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

plt.plot(years, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.show()

# %%
import matplotlib.pyplot as plt

years = list(range(2000, 2012))
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]

plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges'])
plt.show()

# %%
import matplotlib.pyplot as plt

years = list(range(2000, 2012))
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]

plt.figure(figsize=(12, 6))
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title('Crop Yields in Kanto')
plt.legend(['Apples', 'Oranges'])
plt.show()

# %%
import matplotlib.pyplot as plt

x_values = [0, 1, 2, 3, 4, 5]
y_values = [0, 1, 4, 9, 16, 25]

plt.scatter(x_values, y_values, s=30, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.arange(0, 10)
y = np.arange(11, 21)

plt.scatter(x, y, c='r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10)
y = x * x

plt.plot(x, y, 'g--', linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)

plt.title("sine wave form")
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y1 = [10, 12, 14, 16, 18]
y2 = [5, 7, 9, 11, 13]
y3 = [2, 4, 6, 8, 10]

plt.fill_between(x, y1, color="blue")
plt.fill_between(x, y2, color="green")
plt.plot(x, y1, color='red')
plt.plot(x, y2, color='black')

plt.legend(['y1', 'y2'])
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2, 8, 10]
y = [11, 16, 9]

x2 = [3, 9, 11]
y2 = [6, 15, 7]

plt.bar(x, y, color='r')
plt.bar(x2, y2, color='g')
plt.show()

# %%
import matplotlib.pyplot as plt

ages = [2, 5, 70, 40, 30, 45, 50, 45, 43, 40, 44, 60, 7, 13, 57, 18, 90, 77, 32, 21, 20, 40]
range_val = (0, 100)
bins = 10

plt.hist(ages, bins, range_val, color='blue', histtype='bar', rwidth=0.7)
plt.xlabel('age')
plt.ylabel('No. of people')
plt.title('My Histogram')
plt.show()
# Out:
# /tmp/ipykernel_4736/2699201877.py:7: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(ages, bins, range_val, color='blue', histtype='bar', rwidth=0.7)
